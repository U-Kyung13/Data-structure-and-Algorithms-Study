# %% [markdown]
# <a href="https://colab.research.google.com/github/U-Kyung13/Data-structure-and-Algorithms-Study/blob/main/771_Jewels_and_Stones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![화면 캡처 2023-04-02 174607.png](data:image/png;base64,...)

# %%
class Solution:
    def numJewelsInStones(self, J, S):
      ans = 0
      S_cnt = collections.Counter(S)
      for i in S_cnt:
        if i in J:
          ans += S_cnt[i]
      return ans
